# %%
import requests
import pandas as pd

url = "https://api.football-data.org/v4/competitions/"
response = requests.get(url)
# data = response.json()
data=pd.DataFrame(response.json()['competitions'])
data.head()

# df = pd.DataFrame(data['competitions'])
# df.head()
# Out:
#      id                                               area  \
# 0  2176  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 1  2006  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 2  2166  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 3  2023  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
# 4  2024  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
#
#                    name  code    type  \
# 0            Africa Cup    AC     CUP
# 1  WC Qualification CAF  QCAF     CUP
# 2  AFC Champions League   ACL     CUP
# 3    Primera B Nacional   PBN  LEAGUE
# 4      Liga Profesional   ASL  LEAGUE
#
#                                       emblem       plan  \
# 0    https://crests.football-data.org/ac.png  TIER_FOUR
# 1                                       None  TIER_FOUR
# 2                                       None  TIER_FOUR
# 3                                       None  TIER_FOUR
# 4  https://crests.football-data.org/LPDF.svg   TIER_TWO
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        183 non-null    int64
#  1   area                      183 non-null    object
#  2   name                      183 non-null    object
#  3   code                      122 non-null    object
#  4   type                      183 non-null    object
#  5   emblem                    51 non-null     object
#  6   plan                      182 non-null    object
#  7   currentSeason             182 non-null    object
#  8   numberOfAvailableSeasons  183 non-null    int64
#  9   lastUpdated               183 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 14.4+ KB

# %%
df.describe()
# Out:
#                 id  numberOfAvailableSeasons
# count   183.000000                183.000000
# mean   2091.846995                 13.071038
# std      53.614195                 25.112940
# min    2000.000000                  0.000000
# 25%    2045.500000                  3.000000
# 50%    2092.000000                  4.000000
# 75%    2137.500000                  9.000000
# max    2186.000000                145.000000

# %%
df.columns
# Out:
# Index(['id', 'area', 'name', 'code', 'type', 'emblem', 'plan', 'currentSeason',
#        'numberOfAvailableSeasons', 'lastUpdated'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                            0
# area                          0
# name                          0
# code                         61
# type                          0
# emblem                      132
# plan                          1
# currentSeason                 1
# numberOfAvailableSeasons      0
# lastUpdated                   0
# dtype: int64

# %%
df.corr
# Out:
# <bound method DataFrame.corr of        id                                               area  \
# 0    2176  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 1    2166  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 2    2006  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 3    2023  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
# 4    2024  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
# ..    ...                                                ...
# 178  2178  {'id': 2267, 'name': 'World', 'code': 'INT', '...
# 179  2000  {'id': 2267, 'name': 'World', 'code': 'INT', '...
# 180  2155  {'id': 2267, 'name': 'World', 'code': 'INT', '...
# 181  2153  {'id': 2267, 'name': 'World', 'code': 'INT', '...
# 182  2167  {'id': 2267, 'name': 'World', 'code': 'INT', '...
#
#                           name  code    type  \
# 0                   Africa Cup    AC     CUP
# 1         AFC Champions League   ACL     CUP
# 2         WC Qualification CAF  QCAF     CUP
# ...
